# %% [markdown]
# <h1>computational graphs</h1>

# %%
from casadi import *

# %%
x = MX.sym('x',2); # states
u = MX.sym('u'); #controls

# van der pol oscillator system (nonlinear ODE)
ode = vertcat((1 - x[1]**2)*x[0] - x[1] + u, x[0])

# %%
f = Function('f',[x,u],[ode])

# %%
f([0.2,0.8],0.1)
# Out:
# DM([-0.628, 0.2])

# %% [markdown]
# <h1>time integration method</h1>

# %%
T = 10 # time horizon
N = 20 # number of control intervals

# %%
# integrator to discretize the system
dae = {'x':x, 'p':u, 'ode':f(x,u)}
intg = integrator('intg', 'rk', dae, {'tf':T/N, 'number_of_finite_elements':4, 'simplify':True})
# Out:
# CasADi - 2023-10-22 00:51:07 WARNING("The options 't0', 'tf', 'grid' and 'output_t0' have been deprecated.
# The same functionality is provided by providing additional input arguments to the 'integrator' function, in particular:
#  * Call integrator(..., t0, tf, options) for a single output time, or
#  * Call integrator(..., t0, grid, options) for multiple grid points.
# The legacy 'output_t0' option can be emulated by including or excluding 't0' in 'grid'.
# Backwards compatibility is provided in this release only.") [.../casadi/core/integrator.cpp:521]

# %%
res = intg(x0=x,p=u) #evaluate with symbols
x_next = res['xf']

# %%
# Simplify API to (x,u)->(x_next)
F = Function('F',[x,u],[x_next])

# %%
F([0,1],0), F([0.1,0.9],0.1)
# Out:
# (DM([-0.494017, 0.876098]), DM([-0.307745, 0.849043]))

# %% [markdown]
# <h1>concept from functional programming</h1>

# %%
sim = F.mapaccum(N)
x0=[0,1]

# %%
import matplotlib.pyplot as plt
res = sim(x0,cos(range(0,N)))
t = np.linspace(0, T, N+1)
# Create a figure and plot the data
plt.figure()
plt.plot(t, np.concatenate((np.array(x0).reshape((2,1)), res.toarray()), axis=1).T)
plt.legend(['x0 [m/s]', 'x1[m]'])
plt.xlabel('t [s]')
plt.show()

# %% [markdown]
# <h1>symbolic differentiation</h1>

# %%
U = MX.sym('U',N);

X1 = sim(x0, U)[0,:] #Simulate using concrete x0 and symbolic input series

# %%
J = jacobian(X1, U) # jacobian of the first states wrt to input series

Jf = Function('Jf',[U],[J])
plt.spy(Jf(0))

# %% [markdown]
# <h1>Optimal control problem using multiple-shooting</h1>

# %%
opti = Opti() # Optimization problem

x = opti.variable(2,N+1) # decision variable for state trajectory
u = opti.variable(1,N)
p = opti.parameter(2,1) # parameter not optimized over

opti.minimize(sumsqr(x) + sumsqr(u)) 

for k in range(N):
    opti.subject_to(x[:,k+1]==F(x[:,k], u[:,k]))

opti.subject_to(u>=-1)
opti.subject_to(u<=1)
opti.subject_to(x[:,0]==p)

opti
# Out:
# Opti(Opti {
#   instance #0
#   #variables: 2 (nx = 62)
#   #parameters: 1 (np = 2)
#   #constraints: 23 (ng = 82)
#   CasADi solver needs updating.
# })

# %%
# choose a concrete solver
opts = {'qpsol':'qrqp',
                'qpsol_options':{'print_info':False},
                  'qpsol_options':{'print_header':False},
                  'qpsol_options':{'print_iter':False},
                  'print_header':False,
                  'print_iteration':False,
                  'print_time':False
                 }
opti.solver('sqpmethod', opts);

# %% [markdown]
# <h1>from opti (NLP modeling) to casadi functions</h1>

# %%
M = opti.to_function('M',[p],[u[:,0]], ['p'],['u_opt'])
M
# Out:
# -------------------------------------------
# This is casadi::QRQP
# Number of variables:                              62
# Number of constraints:                            82
# Number of nonzeros in H:                         182
# Number of nonzeros in A:                         202
# Number of nonzeros in KKT:                       668
# Number of nonzeros in QR(V):                     521
# Number of nonzeros in QR(R):                     962
# Function(M:(p[2])->(u_opt) MXFunction)

# %%
# opti.set_value(p,[0,1])
sol = opti.solve()

# %%
plt.figure()
plt.plot(t, sol.value(x).T)
plt.stairs(sol.value(u), t )
plt.legend(['x0 [m/s]', 'x1[m]', 'u'])
plt.xlabel('t [s]')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 2
#       1 plt.figure()
# ----> 2 plt.plot(t, sol.value(x).T)
#       3 plt.stairs(sol.value(u), t )
#       4 plt.legend(['x0 [m/s]', 'x1[m]', 'u'])
#
# File ~/dev_ws/src/mpc/mpc_env/lib/python3.9/site-packages/matplotlib/pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/dev_ws/src/mpc/mpc_env/lib/python3.9/site-packages/matplotlib/axes/_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
#    1685 (``'green'``) or hex strings (``'#008000'``).
#    1686 """
#    1687 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
#    1690     self.add_line(line)
#
# File ~/dev_ws/src/mpc/mpc_env/lib/python3.9/site-packages/matplotlib/axes/_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~/dev_ws/src/mpc/mpc_env/lib/python3.9/site-packages/matplotlib/axes/_base.py:504, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     501     self.axes.yaxis.update_units(y)
#     503 if x.shape[0] != y.shape[0]:
# --> 504     raise ValueError(f"x and y must have same first dimension, but "
#     505                      f"have shapes {x.shape} and {y.shape}")
#     506 if x.ndim > 2 or y.ndim > 2:
#     507     raise ValueError(f"x and y can be no greater than 2D, but have "
#     508                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (21,) and (2,)

# %%
# Out:
# -------------------------------------------
# This is casadi::QRQP
# Number of variables:                              62
# Number of constraints:                            82
# Number of nonzeros in H:                         182
# Number of nonzeros in A:                         202
# Number of nonzeros in KKT:                       668
# Number of nonzeros in QR(V):                     521
# Number of nonzeros in QR(R):                     962
# Function(M:(p[2])->(u_opt) MXFunction)

# %%
# MPC loop
import random


X_log = []
U_log = []

x = [0,1]
for i in range(0,4*N):
    u = M(x)
    
    U_log.append(u)
    X_log.append(x)

    # simulate system
    x = F(x,u).toarray().flatten().tolist()
    noise = [0,random.uniform(0, 1)]
    x = [sum(c) for c in zip(x, noise)]
# Out:
# MESSAGE(sqpmethod): Convergence achieved after 4 iterations
# MESSAGE(sqpmethod): No regularity of sensitivities at current point.
# CasADi - 2023-10-22 00:54:00 WARNING("solver:nlp_fg failed: NaN detected for output g, at (row 22, col 0).") [.../casadi/core/oracle_function.cpp:326]
# CasADi - 2023-10-22 00:54:00 WARNING("solver:nlp_fg failed: NaN detected for output g, at (row 22, col 0).") [.../casadi/core/oracle_function.cpp:326]
# CasADi - 2023-10-22 00:54:00 WARNING("solver:nlp_fg failed: NaN detected for output g, at (row 24, col 0).") [.../casadi/core/oracle_function.cpp:326]
# CasADi - 2023-10-22 00:54:00 WARNING("solver:nlp_jac_fg failed: NaN detected for output g, at (row 24, col 0).") [.../casadi/core/oracle_function.cpp:326]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /var/folders/2z/jjqgytld2q16msb4v43rcs440000gn/T/ipykernel_60872/1614413914.py in ?()
#       9 # MPC loop
# ---> 10 import random
#      11
#      12
#      13 X_log = []
#
# ~/dev_ws/src/mpc/mpc_env/lib/python3.9/site-packages/casadi/casadi.py in ?(self, *args, **kwargs)
#   23359       if len(args)>0 and len(kwargs)>0:
#   23360         raise SyntaxError('Function evaluation requires all arguments to be named or none')
#   23361       if len(args)>0:
#   23362     # Ordered inputs -> return tuple
# > 23363         ret = self.call(args)
#   23364         if len(ret)==0:
#   23365           return None
#   23366         elif len(ret)==1:
#
# ~/dev_ws/src/mpc/mpc_env/lib/python3.9/site-packages/casadi/casadi.py in ?(self, *args)
#   20017
#   20018
#   20019
#   20020         """
# > 20021         return _casadi.Function_call(self, *args)
#
# RuntimeError: Error in Function::call for 'M' [MXFunction] at .../casadi/core/function.cpp:330:
# .../casadi/core/function_internal.hpp:1616: Evaluation failed
